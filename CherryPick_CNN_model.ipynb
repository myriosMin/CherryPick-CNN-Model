# %%
import os
import PIL.Image as Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import random
import shutil
import time 
import cv2

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, regularizers, optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D, Reshape, multiply, Add, Activation,
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# List available GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Set memory growth to avoid full allocation
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        print("Using GPU:", gpus[0])
    except RuntimeError as e:
        print(e)
else:
    print("No GPU found.")
# Out:
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# # Data preparation

# %%
root_dir = "/kaggle/input/dataset-transport/dataset_transport/dataset_transport"


# Check the given dataset for classes, splits and instance counts
image_counts = {}

# Loop through all dataset folders (train, test, val, etc.)
for dataset in os.listdir(root_dir):
    dataset_path = os.path.join(root_dir, dataset)

    if os.path.isdir(dataset_path):
        image_counts[dataset] = {}

        # Loop through class folders inside each dataset
        for class_folder in os.listdir(dataset_path):
            class_path = os.path.join(dataset_path, class_folder)

            if os.path.isdir(class_path):
                num_images = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
                image_counts[dataset][class_folder] = num_images

# Display results
for dataset, classes in image_counts.items():
    print(f"{dataset} Dataset:")
    for class_name, count in classes.items():
        print(f"  Class '{class_name}': {count} images")
# Out:
# test Dataset:
#   Class 'airplane': 500 images
#   Class 'truck': 500 images
#   Class 'automobile': 500 images
# train Dataset:
#   Class 'airplane': 2000 images
#   Class 'truck': 2000 images
#   Class 'automobile': 2000 images

# %% [markdown]
# **Insights**
# * 6,000 train and 1,500 test images
# * train and test folders with 75% and 25% split
# * 3 class labels
# * balanced number of instances across 3 classes
# * since the dataset size is small, it's better to not split into another test set but use current test as validation dataset in model optimization

# %%
# View some random images

train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'test')

# Get 2 random images from each class folder
def get_sample_images(dataset_path):
    sample_images = {}

    if os.path.exists(dataset_path):
        for class_folder in os.listdir(dataset_path):
            class_path = os.path.join(dataset_path, class_folder)
            if os.path.isdir(class_path):
                images = [os.path.join(class_path, img) for img in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, img))]
                sample_images[class_folder] = random.sample(images, min(2, len(images)))  # Pick 2 random images
    return sample_images

# Display images
def display_images(dataset_name, samples):
    num_classes = len(samples)
    fig, axes = plt.subplots(num_classes, 2, figsize=(6, 3 * num_classes))

    for i, (class_name, img_paths) in enumerate(samples.items()):
        for j, img_path in enumerate(img_paths):
            img = Image.open(img_path)
            height, width = img.size
            axes[i][j].imshow(img)
            axes[i][j].axis("off")
            axes[i][j].set_title(f"\n{dataset_name} - {class_name} {[height, width]}")

    plt.tight_layout()
    plt.show()

# Get sample images for train and test
train_samples = get_sample_images(train_dir)
test_samples = get_sample_images(val_dir)

# Display images
if train_samples:
    display_images("Train", train_samples)

if test_samples:
    display_images("Val", test_samples)

# %% [markdown]
# **Insights**
# * RGB images
# * (Consistent?) image size of 32x32 in both train & val

# %%
# Data Augmentation for training; since the training size is small, augmentations should be robust while balancing over-and-under fitting.
# A number of different types of augmentations with slight ranges are applied. 

train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values (0-255 → 0-1)
    rotation_range=20,  # Slight rotation of 20 degrees
    width_shift_range=0.1,  # Small horizontal shift of 10%
    height_shift_range=0.1,  # Small vertical shift of 10%
    zoom_range=0.2,  # Random zoom of 20%
    shear_range=0.1,  # Shear transformation of 10%
    horizontal_flip=True,  # Vehicles are symmetrical, so flipping helps; no vertical flip as vehicles rarely stay upside down :")
    fill_mode='nearest'  # Avoid information loss in transformations
)

# No augmentation for validation and test (only rescaling)
val_datagen = ImageDataGenerator(rescale=1./255)

# Generators function with adjustible image size [as transfer learning image size depends on the base model chosen]
def generator_image_size(image_size):
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size),  # Resize images
        batch_size=32,
        class_mode='categorical'
    )
    
    val_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(image_size, image_size),
        batch_size=32,
        class_mode='categorical'
    )
    
    # Print class indices
    print("Class Indices:", train_generator.class_indices)
    # Print image size
    print(f"Current Image Size: {image_size}x{image_size}")

    return train_generator, val_generator

train_generator, val_generator = generator_image_size(32)
# Out:
# Found 6000 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.
# Class Indices: {'airplane': 0, 'automobile': 1, 'truck': 2}
# Current Image Size: 32x32

# %% [markdown]
# # Build CNN model

# %%
""" 
First try: Dense CNN architecture with 3 CNN blocks of 2 layers 
In terms of accuracy, the model did well (90%+), but the training was quite unstable (loss & accuracy spikes), and it had a lot of parameters (3.2M)
"""

# # Define input shape
# input_shape = (32, 32, 3)

# # Build CNN
# CNN_model_233523A = models.Sequential([
#     # Convolutional Blocks
#     Conv2D(64, (3,3), activation='relu', padding='same', input_shape=input_shape, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     BatchNormalization(),
#     Conv2D(64, (3,3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     MaxPooling2D(2,2),
#     Dropout(0.25),

#     Conv2D(128, (3,3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     BatchNormalization(),
#     Conv2D(128, (3,3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     MaxPooling2D(2,2),
#     Dropout(0.25),

#     Conv2D(256, (3,3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     BatchNormalization(),
#     Conv2D(256, (3,3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     MaxPooling2D(2,2),
#     Dropout(0.4),

#     # Fully Connected Layers
#     Flatten(),
#     Dense(512, activation='relu'),
#     Dropout(0.5),
#     Dense(len(train_generator.class_indices), activation='softmax')  # Output: 3 classes
# ])

# CNN_model_233523A.compile(
#     optimizer='adam',
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# # Print summary
# CNN_model_233523A.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_23               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,246,403 (12.38 MB)
#  Trainable params: 3,245,507 (12.38 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
"""
Seecond try: EfficientNet-inspired CNN
EfficientNet was also used in CV module and performed quite well. So, this model is implemented with similar architecture to EfficientNet (width & depth scaling). It had great results but still too many parameters().
"""

# # Input shape
# input_shape = (32, 32, 3)  

# # Swish activation function
# def swish(x):
#     return x * tf.keras.activations.sigmoid(x)

# #  **Fully Fixed Squeeze-and-Excitation (SE) Layer**
# class SEBlock(layers.Layer):
#     def __init__(self, ratio=16, **kwargs):
#         super(SEBlock, self).__init__(**kwargs)
#         self.ratio = ratio
#         self.global_avg_pool = GlobalAveragePooling2D()
    
#     def build(self, input_shape):
#         filters = input_shape[-1]  # Get number of channels (filters)
#         self.dense1 = Dense(max(filters // self.ratio, 1), activation='relu')
#         self.dense2 = Dense(filters, activation='sigmoid')
#         self.reshape = Reshape((1, 1, filters))  # Reshape for broadcasting

#     def call(self, inputs):
#         se = self.global_avg_pool(inputs)  # Squeeze step
#         se = self.dense1(se)
#         se = self.dense2(se)
#         se = self.reshape(se)
#         return multiply([inputs, se])  # Scale input feature maps

#     def compute_output_shape(self, input_shape):
#         return input_shape  # Output shape remains same as input shape

# # **Build EfficientNet-inspired CNN using Sequential API**
# CNN_model_233523A = models.Sequential()

# # First Convolutional Block (Scaled Width & Depth)
# CNN_model_233523A.add(Conv2D(64, (3,3), activation=swish, padding='same', input_shape=input_shape, kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(BatchNormalization())
# CNN_model_233523A.add(Conv2D(64, (3,3), activation=swish, padding='same', kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(SEBlock())  # Apply SE block
# CNN_model_233523A.add(MaxPooling2D((2,2)))
# CNN_model_233523A.add(Dropout(0.2))

# # Second Convolutional Block (Wider + Deeper)
# CNN_model_233523A.add(Conv2D(128, (3,3), activation=swish, padding='same', kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(BatchNormalization())
# CNN_model_233523A.add(Conv2D(128, (3,3), activation=swish, padding='same', kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(SEBlock())  # Apply SE block
# CNN_model_233523A.add(MaxPooling2D((2,2)))
# CNN_model_233523A.add(Dropout(0.3))

# # Third Convolutional Block (Even Deeper + SE Block)
# CNN_model_233523A.add(Conv2D(256, (3,3), activation=swish, padding='same', kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(BatchNormalization())
# CNN_model_233523A.add(Conv2D(256, (3,3), activation=swish, padding='same', kernel_regularizer=regularizers.l2(0.001)))
# CNN_model_233523A.add(SEBlock())  # Apply SE block
# CNN_model_233523A.add(MaxPooling2D((2,2)))
# CNN_model_233523A.add(Dropout(0.4))

# # Global Average Pooling instead of Flatten (EfficientNet-style)
# CNN_model_233523A.add(GlobalAveragePooling2D())
# CNN_model_233523A.add(Dense(512, activation=swish))
# CNN_model_233523A.add(Dropout(0.5))
# CNN_model_233523A.add(Dense(3, activation='softmax'))  # Output for 3 classes

# # Compile model
# CNN_model_233523A.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# # Print model summary
# CNN_model_233523A.summary()
# Out:
# '\nSeecond try: EfficientNet-inspired CNN\n'

# %%
"""
Final CNN: Cherry-pick CNN
Just like the name, this model cherry-picks the good parts from modern state-of-the-art models and combines them seamlessly while being light-weight with great results.
"""

def swish(x):
    return x * tf.keras.activations.sigmoid(x)

def residual_block(x, filters, kernel_regularizer=None):
    """
    Simple ResNet-style block with projection shortcut if filter size changes.
    """
    shortcut = x
    # Project shortcut if filter dimensions change
    if x.shape[-1] != filters:
        shortcut = Conv2D(filters, (1,1), padding='same',
                          kernel_regularizer=kernel_regularizer)(shortcut)
        shortcut = BatchNormalization()(shortcut)
    
    # Main path
    x = Conv2D(filters, (3,3), padding='same',
               kernel_regularizer=kernel_regularizer)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    
    x = Conv2D(filters, (3,3), padding='same',
               kernel_regularizer=kernel_regularizer)(x)
    x = BatchNormalization()(x)
    
    # Add & activate
    x = Add()([x, shortcut])
    x = Activation(swish)(x)
    return x

def depthwise_conv_block(x, filters, kernel_regularizer=None):
    """
    MobileNet-style block: depthwise + pointwise conv.
    """
    x = DepthwiseConv2D((3,3), padding='same',
                        depthwise_regularizer=kernel_regularizer)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    
    x = Conv2D(filters, (1,1), padding='same',
               kernel_regularizer=kernel_regularizer)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    return x

def se_block(input_tensor, ratio=16):
    """
    Squeeze-and-Excitation block to recalibrate channel-wise features.
    """
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    se = Reshape((1, 1, filters))(se)
    return multiply([input_tensor, se])

def build_model(input_shape=(32, 32, 3), num_classes=3, 
                weight_decay=1e-4, 
                drop_rate_conv=0.1, drop_rate_dense=0.3):
    
    inputs = layers.Input(shape=input_shape)
    x = inputs
    
    # VGG-like initial block
    x = Conv2D(32, (3,3), padding='same',
               kernel_regularizer=regularizers.l2(weight_decay))(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    
    x = Conv2D(32, (3,3), padding='same',
               kernel_regularizer=regularizers.l2(weight_decay))(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(drop_rate_conv)(x)
    
    # First residual block
    x = residual_block(x, 64, kernel_regularizer=regularizers.l2(weight_decay))
    x = MaxPooling2D((2,2))(x)
    x = Dropout(drop_rate_conv)(x)
    
    # Depthwise separable block
    x = depthwise_conv_block(x, 128, kernel_regularizer=regularizers.l2(weight_decay))
    x = MaxPooling2D((2,2))(x)
    x = Dropout(drop_rate_conv)(x)
    
    # Second residual block 
    x = residual_block(x, 128, kernel_regularizer=regularizers.l2(weight_decay))
    
    # Squeeze-and-Excitation
    x = se_block(x, ratio=16)
    
    # Classification
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, kernel_regularizer=regularizers.l2(weight_decay))(x)
    x = Activation(swish)(x)
    x = Dropout(drop_rate_dense)(x)
    
    # Label smoothing to reduce overconfidence on small datasets
    loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    
    model.compile(optimizer=optimizers.Adam(learning_rate=0.0005),
                  loss=loss_fn,
                  metrics=['accuracy'])
    return model


CNN_model_233523A = build_model()
CNN_model_233523A.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 32, 32, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 32)     │            896 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 32)     │            128 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 32)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 32)     │          9,248 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 32, 32, 32)     │            128 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 32, 32, 32)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 32)     │              0 │ activation_10[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 16, 32)     │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 64)     │         18,496 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 16, 16, 64)     │            256 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 16, 16, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 16, 16, 64)     │         36,928 │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 64)     │          2,112 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 16, 16, 64)     │            256 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 64)     │            256 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 16, 16, 64)     │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 16, 16, 64)     │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 64)       │              0 │ activation_12[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 8, 8, 64)       │              0 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ depthwise_conv2d_1        │ (None, 8, 8, 64)       │            640 │ dropout_5[0][0]        │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 64)       │            256 │ depthwise_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 8, 8, 64)       │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 8, 8, 128)      │          8,320 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 8, 8, 128)      │            512 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 8, 8, 128)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 4, 4, 128)      │              0 │ activation_14[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 4, 4, 128)      │              0 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 4, 4, 128)      │        147,584 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 4, 4, 128)      │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 4, 4, 128)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 4, 4, 128)      │        147,584 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 4, 4, 128)      │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 4, 4, 128)      │              0 │ batch_normalization_1… │
# │                           │                        │                │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 4, 4, 128)      │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ activation_16[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 8)              │          1,032 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 128)            │          1,152 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 128)      │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 4, 4, 128)      │              0 │ activation_16[0][0],   │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ multiply_1[0][0]       │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 128)            │         16,512 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 128)            │              0 │ dense_6[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128)            │              0 │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 3)              │            387 │ dropout_7[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 393,707 (1.50 MB)
#  Trainable params: 392,299 (1.50 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
epochs = 50 # EarlyStopping will stop before this if necessary
batch_size = 32

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.75, patience=3)
checkpoint = ModelCheckpoint("/kaggle/working/best_model_cnn.keras", monitor='val_accuracy', save_best_only=True, verbose=1)

# Start timer
cnn_train_start = time.time()

# Train the model
cnn_history = CNN_model_233523A.fit(
    train_generator, 
    validation_data=val_generator,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stopping, lr_scheduler, checkpoint]
)

# End timer & get duration 
cnn_train_time = time.time() - cnn_train_start
# Out:
# Epoch 1/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5735 - loss: 1.0089
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.5757 - loss: 1.0065 - val_accuracy: 0.3333 - val_loss: 1.9276 - learning_rate: 5.0000e-04
# Epoch 2/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6894 - loss: 0.8581
# Epoch 2: val_accuracy improved from 0.33333 to 0.35200, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.6902 - loss: 0.8573 - val_accuracy: 0.3520 - val_loss: 1.5418 - learning_rate: 5.0000e-04
# Epoch 3/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7543 - loss: 0.7767
# Epoch 3: val_accuracy improved from 0.35200 to 0.66467, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7545 - loss: 0.7764 - val_accuracy: 0.6647 - val_loss: 0.8754 - learning_rate: 5.0000e-04
# Epoch 4/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7599 - loss: 0.7621
# Epoch 4: val_accuracy improved from 0.66467 to 0.80600, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.7607 - loss: 0.7612 - val_accuracy: 0.8060 - val_loss: 0.6866 - learning_rate: 5.0000e-04
# Epoch 5/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8017 - loss: 0.7133
# Epoch 5: val_accuracy improved from 0.80600 to 0.81400, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.8017 - loss: 0.7130 - val_accuracy: 0.8140 - val_loss: 0.7191 - learning_rate: 5.0000e-04
# Epoch 6/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8270 - loss: 0.6756
# Epoch 6: val_accuracy did not improve from 0.81400
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.8270 - loss: 0.6756 - val_accuracy: 0.7960 - val_loss: 0.6848 - learning_rate: 5.0000e-04
# Epoch 7/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8353 - loss: 0.6511
# Epoch 7: val_accuracy improved from 0.81400 to 0.88000, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.8351 - loss: 0.6514 - val_accuracy: 0.8800 - val_loss: 0.5823 - learning_rate: 5.0000e-04
# Epoch 8/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8485 - loss: 0.6360
# Epoch 8: val_accuracy did not improve from 0.88000
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8483 - loss: 0.6362 - val_accuracy: 0.8673 - val_loss: 0.6064 - learning_rate: 5.0000e-04
# Epoch 9/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8531 - loss: 0.6172
# Epoch 9: val_accuracy improved from 0.88000 to 0.88800, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step - accuracy: 0.8532 - loss: 0.6172 - val_accuracy: 0.8880 - val_loss: 0.5491 - learning_rate: 5.0000e-04
# Epoch 10/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8591 - loss: 0.6089
# Epoch 10: val_accuracy did not improve from 0.88800
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.8588 - loss: 0.6091 - val_accuracy: 0.8767 - val_loss: 0.5765 - learning_rate: 5.0000e-04
# Epoch 11/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8599 - loss: 0.6041
# Epoch 11: val_accuracy did not improve from 0.88800
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8599 - loss: 0.6043 - val_accuracy: 0.8813 - val_loss: 0.5656 - learning_rate: 5.0000e-04
# Epoch 12/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8712 - loss: 0.5923
# Epoch 12: val_accuracy did not improve from 0.88800
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.8710 - loss: 0.5925 - val_accuracy: 0.8867 - val_loss: 0.5548 - learning_rate: 5.0000e-04
# Epoch 13/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8804 - loss: 0.5758
# Epoch 13: val_accuracy improved from 0.88800 to 0.89133, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8802 - loss: 0.5760 - val_accuracy: 0.8913 - val_loss: 0.5465 - learning_rate: 3.7500e-04
# Epoch 14/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8715 - loss: 0.5872
# Epoch 14: val_accuracy did not improve from 0.89133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8716 - loss: 0.5868 - val_accuracy: 0.8853 - val_loss: 0.5479 - learning_rate: 3.7500e-04
# Epoch 15/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8805 - loss: 0.5664
# Epoch 15: val_accuracy improved from 0.89133 to 0.90067, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - accuracy: 0.8805 - loss: 0.5664 - val_accuracy: 0.9007 - val_loss: 0.5190 - learning_rate: 3.7500e-04
# Epoch 16/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8806 - loss: 0.5687
# Epoch 16: val_accuracy improved from 0.90067 to 0.92133, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.8807 - loss: 0.5684 - val_accuracy: 0.9213 - val_loss: 0.4958 - learning_rate: 3.7500e-04
# Epoch 17/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8841 - loss: 0.5532
# Epoch 17: val_accuracy did not improve from 0.92133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.8840 - loss: 0.5534 - val_accuracy: 0.9000 - val_loss: 0.5251 - learning_rate: 3.7500e-04
# Epoch 18/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8919 - loss: 0.5492
# Epoch 18: val_accuracy did not improve from 0.92133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.8918 - loss: 0.5493 - val_accuracy: 0.8933 - val_loss: 0.5426 - learning_rate: 3.7500e-04
# Epoch 19/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8920 - loss: 0.5458
# Epoch 19: val_accuracy did not improve from 0.92133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.8919 - loss: 0.5460 - val_accuracy: 0.8993 - val_loss: 0.5264 - learning_rate: 3.7500e-04
# Epoch 20/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9066 - loss: 0.5245
# Epoch 20: val_accuracy did not improve from 0.92133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.9065 - loss: 0.5247 - val_accuracy: 0.9060 - val_loss: 0.5197 - learning_rate: 2.8125e-04
# Epoch 21/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9012 - loss: 0.5293
# Epoch 21: val_accuracy did not improve from 0.92133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.9014 - loss: 0.5291 - val_accuracy: 0.9120 - val_loss: 0.5134 - learning_rate: 2.8125e-04
# Epoch 22/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8960 - loss: 0.5307
# Epoch 22: val_accuracy improved from 0.92133 to 0.92267, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.8962 - loss: 0.5304 - val_accuracy: 0.9227 - val_loss: 0.4920 - learning_rate: 2.8125e-04
# Epoch 23/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9046 - loss: 0.5256
# Epoch 23: val_accuracy did not improve from 0.92267
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9044 - loss: 0.5258 - val_accuracy: 0.9200 - val_loss: 0.4950 - learning_rate: 2.8125e-04
# Epoch 24/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9097 - loss: 0.5115
# Epoch 24: val_accuracy did not improve from 0.92267
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.9098 - loss: 0.5116 - val_accuracy: 0.8853 - val_loss: 0.5541 - learning_rate: 2.8125e-04
# Epoch 25/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9048 - loss: 0.5183
# Epoch 25: val_accuracy improved from 0.92267 to 0.92533, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.9048 - loss: 0.5184 - val_accuracy: 0.9253 - val_loss: 0.4867 - learning_rate: 2.8125e-04
# Epoch 26/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9158 - loss: 0.5070
# Epoch 26: val_accuracy improved from 0.92533 to 0.92933, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.9156 - loss: 0.5073 - val_accuracy: 0.9293 - val_loss: 0.4820 - learning_rate: 2.8125e-04
# Epoch 27/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9098 - loss: 0.5092
# Epoch 27: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9096 - loss: 0.5094 - val_accuracy: 0.9127 - val_loss: 0.5051 - learning_rate: 2.8125e-04
# Epoch 28/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9127 - loss: 0.5045
# Epoch 28: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.9127 - loss: 0.5047 - val_accuracy: 0.9093 - val_loss: 0.5163 - learning_rate: 2.8125e-04
# Epoch 29/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9145 - loss: 0.5051
# Epoch 29: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9144 - loss: 0.5051 - val_accuracy: 0.9213 - val_loss: 0.4916 - learning_rate: 2.8125e-04
# Epoch 30/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9182 - loss: 0.4958
# Epoch 30: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9183 - loss: 0.4957 - val_accuracy: 0.9260 - val_loss: 0.4831 - learning_rate: 2.1094e-04
# Epoch 31/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9222 - loss: 0.4896
# Epoch 31: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9222 - loss: 0.4896 - val_accuracy: 0.9293 - val_loss: 0.4791 - learning_rate: 2.1094e-04
# Epoch 32/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9180 - loss: 0.4955
# Epoch 32: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9181 - loss: 0.4953 - val_accuracy: 0.9287 - val_loss: 0.4733 - learning_rate: 2.1094e-04
# Epoch 33/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9221 - loss: 0.4888
# Epoch 33: val_accuracy did not improve from 0.92933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9221 - loss: 0.4887 - val_accuracy: 0.9240 - val_loss: 0.4925 - learning_rate: 2.1094e-04
# Epoch 34/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9154 - loss: 0.4940
# Epoch 34: val_accuracy improved from 0.92933 to 0.93200, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9156 - loss: 0.4938 - val_accuracy: 0.9320 - val_loss: 0.4728 - learning_rate: 2.1094e-04
# Epoch 35/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9283 - loss: 0.4771
# Epoch 35: val_accuracy did not improve from 0.93200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9282 - loss: 0.4772 - val_accuracy: 0.9167 - val_loss: 0.4932 - learning_rate: 2.1094e-04
# Epoch 36/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9238 - loss: 0.4824
# Epoch 36: val_accuracy did not improve from 0.93200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9237 - loss: 0.4826 - val_accuracy: 0.9213 - val_loss: 0.4929 - learning_rate: 2.1094e-04
# Epoch 37/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9309 - loss: 0.4724
# Epoch 37: val_accuracy improved from 0.93200 to 0.93533, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9305 - loss: 0.4728 - val_accuracy: 0.9353 - val_loss: 0.4675 - learning_rate: 2.1094e-04
# Epoch 38/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9251 - loss: 0.4750
# Epoch 38: val_accuracy did not improve from 0.93533
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9251 - loss: 0.4752 - val_accuracy: 0.9247 - val_loss: 0.4843 - learning_rate: 2.1094e-04
# Epoch 39/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9234 - loss: 0.4818
# Epoch 39: val_accuracy did not improve from 0.93533
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9233 - loss: 0.4819 - val_accuracy: 0.9340 - val_loss: 0.4667 - learning_rate: 2.1094e-04
# Epoch 40/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9254 - loss: 0.4687
# Epoch 40: val_accuracy did not improve from 0.93533
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9255 - loss: 0.4688 - val_accuracy: 0.9327 - val_loss: 0.4822 - learning_rate: 2.1094e-04
# Epoch 41/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9298 - loss: 0.4766
# Epoch 41: val_accuracy did not improve from 0.93533
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9298 - loss: 0.4766 - val_accuracy: 0.9293 - val_loss: 0.4722 - learning_rate: 2.1094e-04
# Epoch 42/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9224 - loss: 0.4812
# Epoch 42: val_accuracy did not improve from 0.93533
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9223 - loss: 0.4814 - val_accuracy: 0.9267 - val_loss: 0.4749 - learning_rate: 2.1094e-04
# Epoch 43/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9370 - loss: 0.4613
# Epoch 43: val_accuracy improved from 0.93533 to 0.93667, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9370 - loss: 0.4614 - val_accuracy: 0.9367 - val_loss: 0.4609 - learning_rate: 1.5820e-04
# Epoch 44/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9241 - loss: 0.4803
# Epoch 44: val_accuracy improved from 0.93667 to 0.93933, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9241 - loss: 0.4802 - val_accuracy: 0.9393 - val_loss: 0.4580 - learning_rate: 1.5820e-04
# Epoch 45/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9328 - loss: 0.4640
# Epoch 45: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9329 - loss: 0.4638 - val_accuracy: 0.9240 - val_loss: 0.4900 - learning_rate: 1.5820e-04
# Epoch 46/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9271 - loss: 0.4715
# Epoch 46: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.9272 - loss: 0.4714 - val_accuracy: 0.9233 - val_loss: 0.4863 - learning_rate: 1.5820e-04
# Epoch 47/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9370 - loss: 0.4557
# Epoch 47: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.9369 - loss: 0.4559 - val_accuracy: 0.9327 - val_loss: 0.4630 - learning_rate: 1.5820e-04
# Epoch 48/50
# 181/188 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9308 - loss: 0.4621
# Epoch 48: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9309 - loss: 0.4620 - val_accuracy: 0.9347 - val_loss: 0.4689 - learning_rate: 1.1865e-04
# Epoch 49/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9440 - loss: 0.4478
# Epoch 49: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.9439 - loss: 0.4479 - val_accuracy: 0.9340 - val_loss: 0.4641 - learning_rate: 1.1865e-04
# Epoch 50/50
# 182/188 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9346 - loss: 0.4648
# Epoch 50: val_accuracy improved from 0.93933 to 0.94333, saving model to /kaggle/working/best_model_cnn.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9347 - loss: 0.4645 - val_accuracy: 0.9433 - val_loss: 0.4518 - learning_rate: 1.1865e-04

# %%
# Placeholder for metrics for comparison
cnn_metrics = {}

def get_sample_image(path, input_size):
    sample_image = Image.open(path)  
    sample_image = np.array(sample_image)
    sample_image = cv2.resize(sample_image, input_size)
    sample_image = np.expand_dims(sample_image, axis=0)
    return sample_image
    
def collect_1(model, history, metrics_dict, train_time, input_size):
    
    # Store accuracy metrics (from best epoch)
    best_epoch = np.argmax(history.history["val_accuracy"])  
    metrics_dict["Validation Accuracy"] = history.history["val_accuracy"][best_epoch]
    metrics_dict["Training Accuracy"] = history.history["accuracy"][best_epoch]  
    
    # Compute Overfitting Gap
    metrics_dict["Overfitting Gap"] = metrics_dict["Training Accuracy"] - metrics_dict["Validation Accuracy"]

    # Compute Time per Epoch
    metrics_dict["Training Time (Total)"] = train_time
    metrics_dict["Training Time per Epoch"] = train_time / len(history.history["accuracy"])
    
    # Measure Inference Speed (Prediction Time per Image)
    sample_image = get_sample_image("/kaggle/input/dataset-transport/Mins/Mins/test_car.png", input_size) # Sample car image from test folder
    start_time = time.time()
    model.predict(np.expand_dims(sample_image[0], axis=0))
    metrics_dict["Inference Speed"] = time.time() - start_time  # Time per image

    # Print Metrics 
    print(f"{str(model)} Metrics Status: ")
    print("="*40)
    for metric, value in metrics_dict.items():
        if isinstance(value, float):  
            print(f"{metric}: {value:.4f}")
        else:
            print(f"{metric}: {value}")
    print("="*40)

    return metrics_dict

cnn_metrics = collect_1(CNN_model_233523A, cnn_history, cnn_metrics, cnn_train_time, (32,32))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# <Functional name=functional_1, built=True> Metrics Status:
# ========================================
# Validation Accuracy: 0.9433
# Training Accuracy: 0.9367
# Overfitting Gap: -0.0067
# Training Time (Total): 568.3459
# Training Time per Epoch: 11.3669
# Inference Speed: 1.0261
# ========================================

# %%
# Plot training and validation metrics

def plot_training_history(history):
    plt.figure(figsize=(12,5))

    # Accuracy Plot
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim([0,1])
    plt.legend()
    plt.title('Model Accuracy')

    # Loss Plot
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Model Loss')
    plt.savefig('/kaggle/working/train_val.png')
    plt.show()

plot_training_history(cnn_history)

# %%
# Visualize feature maps

def feature_maps_visualization(model, input_size):
    # Take out conv layers
    conv_layers = [i for i in range(len(model.layers)) if 'conv' in model.layers[i].name]
    
    # Load a pre-selected image for better comparison
    sample_image = get_sample_image("/kaggle/input/dataset-transport/Mins/Mins/test_car.png", input_size) # Sample car image from test folder
    feature_maps = []
    
    for layer_idx in conv_layers:
        activation_model = Model(inputs=model.inputs, outputs=model.layers[layer_idx].output)
        activation = activation_model.predict(sample_image)
    
        print(model.layers[layer_idx])  # Print layer details
    
        plt.figure(figsize=(5,5))
        for filter_idx in range(3):  # Show first 3 filters
            plt.subplot(1, 3, filter_idx+1)
            plt.imshow(activation[0, :, :, filter_idx], cmap="viridis")
            plt.axis("off")  #  Ensures each subplot is properly formatted
    
        # Save each feature map separately
        feature_path = f"/kaggle/working/feature_maps_layer_cnn_{layer_idx}.png"
        plt.savefig(feature_path) 
        feature_maps.append(feature_path)
        plt.show()

    return feature_maps

cnn_metrics["Feature Maps"] = feature_maps_visualization(CNN_model_233523A, (32,32))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# <Conv2D name=conv2d_8, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# <Conv2D name=conv2d_9, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# <Conv2D name=conv2d_11, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# <Conv2D name=conv2d_12, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# <Conv2D name=conv2d_10, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# <DepthwiseConv2D name=depthwise_conv2d_1, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# <Conv2D name=conv2d_13, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# <Conv2D name=conv2d_14, built=True>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# <Conv2D name=conv2d_15, built=True>

# %%
# Collect model size and no. of parameters

def collect_2(model, model_path, metrics_dict):
    # Compute Model Size
    model.save(model_path)
    metrics_dict["Model Size (MB)"] = os.path.getsize(model_path) / 1024 / 1024
    
    # Compute Number of Parameters
    metrics_dict["Number of Parameters"] = model.count_params()
    
    return metrics_dict

cnn_metrics = collect_2(CNN_model_233523A, "/kaggle/working/cnn_model.keras", cnn_metrics)

# %% [markdown]
# # Summary of CNN model development

# %% [markdown]
# (<150 words): to describe your key considerations on
# design strategy, overfitting techniques, evaluation & optimization.

# %%
plot_model(CNN_model_233523A, to_file="cnn_model_structure.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# **Cherry-Pick CNN Process Flow** (FYI only; not for marking)
#
# As a 32×32×3 image enters the model, it first passes through two 3×3 convolutional layers with 32 filters to extract edges and textures. Batch normalization stabilizes activations, and Swish activation improves learning while MaxPooling (2×2) reduces the size to 16×16×32, and dropout (10%) prevents overfitting.
#
# Next, a ResNet-style residual block with 64 filters processes the image. A shortcut connection helps retain information, preventing gradient loss. Another MaxPooling (2×2) reduces the size to 8×8×64, followed by dropout for regularization.
#
# The model then applies a depthwise separable convolution block like MobileNet. Depthwise convolution processes each channel separately, while pointwise convolution (1×1) merges features. This reduces computation while maintaining accuracy. Batch normalization, Swish activation, and MaxPooling (2×2) shrink the size to 4×4×128, with dropout to avoid overfitting.
#
# Another residual block with 128 filters refines the features. A Squeeze-and-Excitation (SE) block enhances important channels by recalibrating their weights. Global Average Pooling (GAP) compresses each feature map into a single value. Two dense layers adjust the feature weights before multiplying them back into the original features.
#
# Starting with Fully-Connected layers, GAP converts the 4×4×128 tensor into a 128-dimensional vector. A dense layer with 128 neurons processes it, followed by Swish activation and dropout (30%).
#
# Finally, a softmax layer predicts class probabilities. Label smoothing (0.1) prevents overconfidence. The model is compiled using the Adam optimizer (lr = 0.0005), categorical crossentropy loss, and accuracy as the evaluation metric.
#
# This model combines techniques from VGG, ResNet, MobileNet, and EfficientNet, ensuring high accuracy while being lightweight and efficient and clearly outperforms other CNNs.

# %% [markdown]
# ## CNN Model Considerations (for Marking) [162 words]
#
# **Obvious Challenges**
# * Small data size: With only 6,000 images, the risk of overfitting is high. Data augmentation (six transformations) introduces variability and improves generalization.
# * Overfitting: L2 regularization, dropout, and batch normalization prevent excessive parameter tuning. Global Average Pooling (GAP) reduces both overfitting and parameter count.
# * Evaluation: Since datasets are balanced across three classes and no background information is given, accuracy is a reliable performance metric (val_accuracy: 0.9433
# train_ccuracy: 0.9367). Feature map visualization confirms lower layers detect simple patterns, while deeper layers extract complex details.
# * Optimization: Adam optimizer, Swish activation, early stopping, and ReduceLROnPlateau ensure stable training and faster convergence.
#
# **Trial-and-Error Challenges**
# * Low Resolution: 32×32 images lack detail, so deeper VGG blocks are required for feature extraction.
# * Vanishing Gradient: Some feature maps turned blank in CNN_1 and CNN_2. ResNet residual connections fix this by allowing gradients to flow.
# * Efficiency: SE blocks dynamically recalibrate feature importance for better resource use.
# * Model Complexity: MobileNet’s depthwise separable convolutions reduce parameters, keeping the model lightweight without compromising accuracy.

# %% [markdown]
# # Build Transfer Learning model

# %%
# MobileNetV2 is chosen for its ligh-weightedness and compatiability with low-resolution images
# It has its own preprocessing steps [-1,1] instead of [0,1], so previous ImageDataGenerator is adjusted accordingly while keeping the same augmentation 

train_datagen = ImageDataGenerator(
    rotation_range=20,  # Slight rotation of 20 degrees
    width_shift_range=0.1,  # Small horizontal shift of 10%
    height_shift_range=0.1,  # Small vertical shift of 10%
    zoom_range=0.2,  # Random zoom of 20%
    shear_range=0.1,  # Shear transformation of 10%
    horizontal_flip=True,  # Vehicles are symmetrical, so flipping helps; no vertical flip as vehicles rarely stay upside down :")
    fill_mode='nearest'  # Avoid information loss in transformations
)

# No augmentation for validation
val_datagen = ImageDataGenerator()

train_generator, val_generator = generator_image_size(96)
# Out:
# Found 6000 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.
# Class Indices: {'airplane': 0, 'automobile': 1, 'truck': 2}
# Current Image Size: 96x96

# %%
# Define transfer learning model
def create_mobilenet_feature_extractor(input_shape=(96, 96, 3), num_classes=3):
    
    # Load MobileNetV2 
    base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=input_shape)
    
    # Freeze all layers
    base_model.trainable = False
    
    # Build the model (using the Functional API for flexibility)
    inputs = layers.Input(shape=input_shape)
    
    # Apply MobileNetV2 preprocessing
    x = preprocess_input(inputs)
    
    x = base_model(x, training=False)  # Force inference mode
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(128, activation="relu")(x)  
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-3),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    
    return model

# Create the feature extractor model
TL_model_233523A = create_mobilenet_feature_extractor()
TL_model_233523A.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide (TrueDivide)             │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract (Subtract)                  │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_96 (Functional)     │ (None, 3, 3, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,427,459 (9.26 MB)
#  Trainable params: 166,915 (652.01 KB)
#  Non-trainable params: 2,260,544 (8.62 MB)

# %%
# Initial Feature Extraction
epochs = 15
batch_size = 32

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
checkpoint = ModelCheckpoint("/kaggle/working/best_model_transfer.keras", monitor='val_accuracy', save_best_only=True, verbose=1)

tl_extraction_start = time.time()

# Train feature extraction model
history = TL_model_233523A.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[early_stopping, lr_scheduler, checkpoint]
)
tl_extraction_duration = time.time() - tl_extraction_start
# Out:
# Epoch 1/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7969 - loss: 0.5531
# Epoch 1: val_accuracy improved from -inf to 0.85867, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 38s 153ms/step - accuracy: 0.7972 - loss: 0.5525 - val_accuracy: 0.8587 - val_loss: 0.3501 - learning_rate: 0.0010
# Epoch 2/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8895 - loss: 0.3060
# Epoch 2: val_accuracy improved from 0.85867 to 0.88067, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8896 - loss: 0.3060 - val_accuracy: 0.8807 - val_loss: 0.3348 - learning_rate: 0.0010
# Epoch 3/15
# 186/188 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9043 - loss: 0.2550
# Epoch 3: val_accuracy improved from 0.88067 to 0.88333, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 24s 123ms/step - accuracy: 0.9042 - loss: 0.2552 - val_accuracy: 0.8833 - val_loss: 0.3162 - learning_rate: 0.0010
# Epoch 4/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9033 - loss: 0.2474
# Epoch 4: val_accuracy improved from 0.88333 to 0.89333, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.9033 - loss: 0.2474 - val_accuracy: 0.8933 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 5/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9123 - loss: 0.2252
# Epoch 5: val_accuracy did not improve from 0.89333
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.9123 - loss: 0.2252 - val_accuracy: 0.8800 - val_loss: 0.3070 - learning_rate: 0.0010
# Epoch 6/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9127 - loss: 0.2164
# Epoch 6: val_accuracy did not improve from 0.89333
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9127 - loss: 0.2163 - val_accuracy: 0.8927 - val_loss: 0.2967 - learning_rate: 0.0010
# Epoch 7/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9177 - loss: 0.2182
# Epoch 7: val_accuracy improved from 0.89333 to 0.89533, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 113ms/step - accuracy: 0.9177 - loss: 0.2182 - val_accuracy: 0.8953 - val_loss: 0.2858 - learning_rate: 0.0010
# Epoch 8/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9195 - loss: 0.2176
# Epoch 8: val_accuracy improved from 0.89533 to 0.89933, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9195 - loss: 0.2176 - val_accuracy: 0.8993 - val_loss: 0.2887 - learning_rate: 0.0010
# Epoch 9/15
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9305 - loss: 0.1757
# Epoch 9: val_accuracy improved from 0.89933 to 0.90067, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.9304 - loss: 0.1759 - val_accuracy: 0.9007 - val_loss: 0.3017 - learning_rate: 0.0010
# Epoch 10/15
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9278 - loss: 0.2010
# Epoch 10: val_accuracy did not improve from 0.90067
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9278 - loss: 0.2010 - val_accuracy: 0.8860 - val_loss: 0.3291 - learning_rate: 0.0010
# Epoch 11/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9284 - loss: 0.1879
# Epoch 11: val_accuracy did not improve from 0.90067
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.9284 - loss: 0.1879 - val_accuracy: 0.8820 - val_loss: 0.3205 - learning_rate: 5.0000e-04
# Epoch 12/15
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9367 - loss: 0.1641
# Epoch 12: val_accuracy did not improve from 0.90067
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9367 - loss: 0.1642 - val_accuracy: 0.8927 - val_loss: 0.2945 - learning_rate: 5.0000e-04
# Epoch 13/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9395 - loss: 0.1600
# Epoch 13: val_accuracy did not improve from 0.90067
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.9395 - loss: 0.1601 - val_accuracy: 0.8840 - val_loss: 0.3072 - learning_rate: 5.0000e-04
# Epoch 14/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9339 - loss: 0.1710
# Epoch 14: val_accuracy did not improve from 0.90067
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.9339 - loss: 0.1710 - val_accuracy: 0.8973 - val_loss: 0.2925 - learning_rate: 2.5000e-04

# %%
# Fully-connected block is starting to overfit on the training data.
# Unfreeze some layers of base model to see if the model can still learn.

print(f"MobileNetV2 has {len(MobileNetV2(weights='imagenet', include_top=False, input_shape=input_shape).layers)} layers.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# MobileNetV2 has 154 layers.

# %% [markdown]
# **MobileNetV2 Architecture**
# * Shallow Layers (0-30): Capture edges, textures (should remain frozen).
# * Mid Layers (30-100): Capture shapes, patterns (may be fine-tuned slightly).
# * Deep Layers (100+): Capture specific object details (best for fine-tuning).

# %%
# Unfreeze & re-compile with new learning rate
def fine_tune_mobilenet(model, fine_tune_at=100, lr=1e-5):
    # Unfreeze some layers
    base_model = model.layers[1]  # MobileNetV2 base model
    base_model.trainable = True

    # Freeze first 'fine_tune_at' layers, train the rest
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Recompile the model with a lower learning rate
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),  #  Lower LR for fine-tuning
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# Fine-tune the model with lower learning rate
TL_ft_model_233523A = fine_tune_mobilenet(TL_model_233523A, fine_tune_at=100, lr=0.0001) 
TL_ft_model_233523A.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide (TrueDivide)             │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract (Subtract)                  │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_96 (Functional)     │ (None, 3, 3, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_18               │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,427,459 (9.26 MB)
#  Trainable params: 2,028,355 (7.74 MB)
#  Non-trainable params: 399,104 (1.52 MB)

# %%
tl_finetune_start = time.time()

# Train the fine-tuned model
tl_history_1 = TL_ft_model_233523A.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,  
    batch_size=batch_size,
    callbacks=[early_stopping, lr_scheduler, checkpoint]
)

tl_finetune_duration_1 = time.time() - tl_finetune_start
# Out:
# Epoch 1/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8717 - loss: 0.3395
# Epoch 1: val_accuracy improved from 0.90067 to 0.91667, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 176ms/step - accuracy: 0.8721 - loss: 0.3387 - val_accuracy: 0.9167 - val_loss: 0.2588 - learning_rate: 1.0000e-04
# Epoch 2/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9152 - loss: 0.2516
# Epoch 2: val_accuracy did not improve from 0.91667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 116ms/step - accuracy: 0.9152 - loss: 0.2511 - val_accuracy: 0.8700 - val_loss: 0.3819 - learning_rate: 1.0000e-04
# Epoch 3/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9420 - loss: 0.1701
# Epoch 3: val_accuracy improved from 0.91667 to 0.92667, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9419 - loss: 0.1702 - val_accuracy: 0.9267 - val_loss: 0.2251 - learning_rate: 1.0000e-04
# Epoch 4/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9441 - loss: 0.1430
# Epoch 4: val_accuracy did not improve from 0.92667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.9440 - loss: 0.1433 - val_accuracy: 0.9007 - val_loss: 0.2964 - learning_rate: 1.0000e-04
# Epoch 5/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9526 - loss: 0.1265
# Epoch 5: val_accuracy did not improve from 0.92667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - accuracy: 0.9526 - loss: 0.1265 - val_accuracy: 0.9253 - val_loss: 0.2442 - learning_rate: 1.0000e-04
# Epoch 6/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9680 - loss: 0.0975
# Epoch 6: val_accuracy did not improve from 0.92667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.9679 - loss: 0.0978 - val_accuracy: 0.9187 - val_loss: 0.2493 - learning_rate: 1.0000e-04
# Epoch 7/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9681 - loss: 0.0980
# Epoch 7: val_accuracy did not improve from 0.92667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.9681 - loss: 0.0979 - val_accuracy: 0.9133 - val_loss: 0.2583 - learning_rate: 5.0000e-05
# Epoch 8/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9655 - loss: 0.0884
# Epoch 8: val_accuracy improved from 0.92667 to 0.93667, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 116ms/step - accuracy: 0.9655 - loss: 0.0883 - val_accuracy: 0.9367 - val_loss: 0.1857 - learning_rate: 5.0000e-05
# Epoch 9/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9742 - loss: 0.0739
# Epoch 9: val_accuracy did not improve from 0.93667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - accuracy: 0.9741 - loss: 0.0740 - val_accuracy: 0.9367 - val_loss: 0.1766 - learning_rate: 5.0000e-05
# Epoch 10/10
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9735 - loss: 0.0709
# Epoch 10: val_accuracy did not improve from 0.93667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 24s 123ms/step - accuracy: 0.9735 - loss: 0.0709 - val_accuracy: 0.9347 - val_loss: 0.1826 - learning_rate: 5.0000e-05

# %%
# Val accuracy noticeably improved although slight overfitting still exists.

# Fine-tune the model more with lower learning rate
TL_ft_model_233523A3 = fine_tune_mobilenet(TL_model_233523A, fine_tune_at=50, lr=0.00001) 
TL_ft_model_233523A3.summary()
# Out:
# Model: "functional_68"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)          │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide_4 (TrueDivide)           │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract_4 (Subtract)                │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_96 (Functional)     │ (None, 3, 3, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_8           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_22               │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,427,459 (9.26 MB)
#  Trainable params: 2,341,507 (8.93 MB)
#  Non-trainable params: 85,952 (335.75 KB)

# %%
# Final push
tl_finetune_start = time.time()

# Train the fine-tuned model
tl_history_2 = TL_ft_model_233523A.fit(
    train_generator,
    validation_data=val_generator,
    epochs=5,  
    batch_size=batch_size,
    callbacks=[early_stopping, lr_scheduler, checkpoint]
)

tl_finetune_duration_2 = time.time() - tl_finetune_start
# Out:
# Epoch 1/5
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9752 - loss: 0.0674
# Epoch 1: val_accuracy did not improve from 0.93667
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.9752 - loss: 0.0674 - val_accuracy: 0.9367 - val_loss: 0.1717 - learning_rate: 1.0000e-05
# Epoch 2/5
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9732 - loss: 0.0708
# Epoch 2: val_accuracy improved from 0.93667 to 0.93933, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.9732 - loss: 0.0708 - val_accuracy: 0.9393 - val_loss: 0.1715 - learning_rate: 1.0000e-05
# Epoch 3/5
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9743 - loss: 0.0672
# Epoch 3: val_accuracy did not improve from 0.93933
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9743 - loss: 0.0672 - val_accuracy: 0.9393 - val_loss: 0.1672 - learning_rate: 1.0000e-05
# Epoch 4/5
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9776 - loss: 0.0618
# Epoch 4: val_accuracy improved from 0.93933 to 0.94133, saving model to /kaggle/working/best_model_transfer.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9776 - loss: 0.0619 - val_accuracy: 0.9413 - val_loss: 0.1670 - learning_rate: 1.0000e-05
# Epoch 5/5
# 185/188 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9812 - loss: 0.0553
# Epoch 5: val_accuracy did not improve from 0.94133
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.9812 - loss: 0.0552 - val_accuracy: 0.9407 - val_loss: 0.1670 - learning_rate: 1.0000e-05

# %%
# Although slight overfitting seems inevitable, increased val accuracy may suffice it.

# Combine history dictionaries
def merge_histories(histories):
    merged_history = {'loss': [], 'val_loss': [], 'accuracy': [], 'val_accuracy': []}

    for h in histories:
        merged_history['loss'].extend(h.history['loss'])
        merged_history['val_loss'].extend(h.history['val_loss'])
        merged_history['accuracy'].extend(h.history['accuracy'])
        merged_history['val_accuracy'].extend(h.history['val_accuracy'])

    return merged_history

# Merge all histories
full_tl_history = merge_histories([history, tl_history_1, tl_history_2])

# %%
# Plot Accuracy
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(full_tl_history['accuracy'], label='Train Accuracy')
plt.plot(full_tl_history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0,1])
plt.title('Model Accuracy Over Fine-Tuning')
plt.legend()

# Plot Loss
plt.subplot(1,2,2)
plt.plot(full_tl_history['loss'], label='Train Loss')
plt.plot(full_tl_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss Over Fine-Tuning')
plt.legend()

plt.show()

# %%
# Collect metrics for later comparison
tl_metrics = {}
tl_train_time = tl_extraction_duration + tl_finetune_duration_1 + tl_finetune_duration_2
tl_metrics = collect_1(TL_ft_model_233523A, tl_history_2, tl_metrics, tl_train_time, (96, 96))
tl_metrics["Training Time per Epoch"] = tl_train_time / 30
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# <Functional name=functional_11, built=True> Metrics Status:
# ========================================
# Validation Accuracy: 0.9413
# Training Accuracy: 0.9757
# Overfitting Gap: 0.0343
# Training Time (Total): 714.4994
# Training Time per Epoch: 142.8999
# Inference Speed: 3.1220
# ========================================

# %%
# Visualize feature maps
def feature_maps_visualization(model, input_size):
    # Extract the base MobileNetV2 model from the fine-tuned model
    base_model = model.layers[1]  # First layer is the MobileNetV2 base model

    # Find convolutional and depthwise conv layers inside the base model
    conv_layers = [layer for layer in base_model.layers if 'conv' in layer.name or 'depthwise' in layer.name]

    # Load a pre-selected image for better comparison
    sample_image = get_sample_image("/kaggle/input/dataset-transport/Mins/Mins/test_car.png", input_size) # Sample car image from test folder
    feature_maps = []
    
    for layer in conv_layers:
        activation_model = Model(inputs=base_model.input, outputs=layer.output)
        activation = activation_model.predict(sample_image)

        print(f"Visualizing Layer: {layer.name} | Shape: {activation.shape}")
        
        # ✅ Plot Feature Maps (show max 3 feature maps per layer)
        num_filters = min(activation.shape[-1], 3)  # Max 3 filters
        plt.figure(figsize=(5, 5))
        
        for filter_idx in range(num_filters):  
            plt.subplot(1, num_filters, filter_idx+1)
            plt.imshow(activation[0, :, :, filter_idx], cmap="viridis")
            plt.axis("off")
        
        # ✅ Save and display feature map
        feature_path = f"/kaggle/working/feature_maps_tl_{layer.name}.png"
        plt.savefig(feature_path) 
        feature_maps.append(feature_path)
        plt.show()

    return feature_maps

# ✅ Apply to MobileNetV2 Model
tl_metrics["Feature Maps"] = feature_maps_visualization(TL_ft_model_233523A, (96,96))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Visualizing Layer: expanded_conv_depthwise | Shape: (1, 48, 48, 32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Visualizing Layer: expanded_conv_depthwise_BN | Shape: (1, 48, 48, 32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Visualizing Layer: expanded_conv_depthwise_relu | Shape: (1, 48, 48, 32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Visualizing Layer: expanded_conv_project | Shape: (1, 48, 48, 16)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Visualizing Layer: expanded_conv_project_BN | Shape: (1, 48, 48, 16)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# Visualizing Layer: block_1_depthwise | Shape: (1, 24, 24, 96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Visualizing Layer: block_1_depthwise_BN | Shape: (1, 24, 24, 96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Visualizing Layer: block_1_depthwise_relu | Shape: (1, 24, 24, 96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Visualizing Layer: block_2_depthwise | Shape: (1, 24, 24, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# Visualizing Layer: block_2_depthwise_BN | Shape: (1, 24, 24, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# Visualizing Layer: block_2_depthwise_relu | Shape: (1, 24, 24, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# Visualizing Layer: block_3_depthwise | Shape: (1, 12, 12, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Visualizing Layer: block_3_depthwise_BN | Shape: (1, 12, 12, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# Visualizing Layer: block_3_depthwise_relu | Shape: (1, 12, 12, 144)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step
# Visualizing Layer: block_4_depthwise | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step
# Visualizing Layer: block_4_depthwise_BN | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# Visualizing Layer: block_4_depthwise_relu | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# Visualizing Layer: block_5_depthwise | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# Visualizing Layer: block_5_depthwise_BN | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_5_depthwise_relu | Shape: (1, 12, 12, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_6_depthwise | Shape: (1, 6, 6, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_6_depthwise_BN | Shape: (1, 6, 6, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_6_depthwise_relu | Shape: (1, 6, 6, 192)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_7_depthwise | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_7_depthwise_BN | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_7_depthwise_relu | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_8_depthwise | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_8_depthwise_BN | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_8_depthwise_relu | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Visualizing Layer: block_9_depthwise | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_9_depthwise_BN | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_9_depthwise_relu | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_10_depthwise | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_10_depthwise_BN | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_10_depthwise_relu | Shape: (1, 6, 6, 384)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_11_depthwise | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_11_depthwise_BN | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_11_depthwise_relu | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_12_depthwise | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_12_depthwise_BN | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_12_depthwise_relu | Shape: (1, 6, 6, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_13_depthwise | Shape: (1, 3, 3, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_13_depthwise_BN | Shape: (1, 3, 3, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_13_depthwise_relu | Shape: (1, 3, 3, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_14_depthwise | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_14_depthwise_BN | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_14_depthwise_relu | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Visualizing Layer: block_15_depthwise | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_15_depthwise_BN | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_15_depthwise_relu | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_16_depthwise | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_16_depthwise_BN | Shape: (1, 3, 3, 960)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Visualizing Layer: block_16_depthwise_relu | Shape: (1, 3, 3, 960)

# %%
tl_metrics = collect_2(TL_ft_model_233523A, "/kaggle/working/tl_model.keras", tl_metrics)
tl_metrics['Trainable Parameters'] = 2341507
tl_metrics['Non-trainable Parameters'] = 85952

# %% [markdown]
# # Summary of Transfer Learning model development

# %% [markdown]
# (<150 words): to describe your key
# considerations on pre-trained model selection, tuning strategies, overfitting techniques, evaluation & optimization.

# %%
plot_model(TL_ft_model_233523A, to_file="tl_model_structure.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Transfer Learning Model Considerations (189 words)
# * BaseModel Selection: Most pre-trained models are trained on ImageNet (224×224 pixels), but upscaling 32×32 to 224×224 does not create meaningful features. Instead, MobileNetV2 is chosen for its lightweight architecture and compatibility with low-resolution images (reasonable upscaling to 96×96), providing efficient feature extraction.
# * Preprocessing-and-Augmentation: MobileNetV2 processes inputs in the [-1,1] range, requiring adjustments in ImageDataGenerator. Meanwhile, using the same augmentations as the CNN model ensures a fair comparison.
# * Feature Extraction: Since the dataset is small but similar to ImageNet, the model is trained for 15 epochs with all layers frozen and LR = 0.001 for noticeable updates. (train_accuracy: 0.9304, val_accuracy: 0.9007)
# * Fine-tuning Strategy: To improve accuracy, the last 50 layers are unfrozen and trained for 10 epochs at 0.0001 LR. Later, 100 layers are unfrozen with 0.00001 LR for stability.
# * Overfitting: Dropout, L2 regularization, and batch normalization are applied. More augmentations could reduce overfitting but would affect fairness in comparison with the CNN model.
# * Optimization-and-Evaluation: Early stopping, ReduceLROnPlateau, and Adam optimizer ensure smooth convergence. The model is slightly overfitted (Val_acc: 94.13%, Train_acc: 97.57%). Some feature maps appear blank, but with 157 layers, the rest function correctly, extracting both low-level spatial structures and high-level intricate details.

# %% [markdown]
# # Comparison of the 2 models (CNN and Transfer Learning)

# %%
print("Available CNN Model Stats: ")
print(cnn_metrics.keys())
print("\nAvailable TL Model Stats: ")
print(tl_metrics.keys())
# Out:
# Available CNN Model Stats:
# dict_keys(['Validation Accuracy', 'Training Accuracy', 'Overfitting Gap', 'Training Time (Total)', 'Training Time per Epoch', 'Inference Speed', 'Feature Maps', 'Model Size (MB)', 'Number of Parameters'])
#
# Available TL Model Stats:
# dict_keys(['Validation Accuracy', 'Training Accuracy', 'Overfitting Gap', 'Training Time (Total)', 'Training Time per Epoch', 'Inference Speed', 'Feature Maps', 'Model Size (MB)', 'Number of Parameters', 'Trainable Parameters', 'Non-trainable Parameters'])

# %%
# Create a DataFrame for comparison
comparison_data = {
    "Metric": [
        "Validation Accuracy", 
        "Training Accuracy", 
        "Overfitting Gap",
        "Training Time (Total)", 
        "Training Time per Epoch",
        "Inference Speed",
        "Model Size (MB)", 
        "Number of Parameters",
        "Trainable Parameters", 
        "Non-trainable Parameters"
    ],
    "Custom CNN": [
        cnn_metrics.get("Validation Accuracy"),  
        cnn_metrics.get("Training Accuracy"),  
        cnn_metrics.get("Overfitting Gap"),  
        cnn_metrics.get("Training Time (Total)"),  
        cnn_metrics.get("Training Time per Epoch"),  
        cnn_metrics.get("Inference Speed"),  
        cnn_metrics.get("Model Size (MB)"),  
        cnn_metrics.get("Number of Parameters"),  
        "-",  # CNN doesn't have frozen layers
        "-"   # CNN doesn't have frozen layers
    ],
    "Transfer Learning (TL)": [
        tl_metrics.get("Validation Accuracy"),  
        tl_metrics.get("Training Accuracy"),  
        tl_metrics.get("Overfitting Gap"),   
        tl_metrics.get("Training Time (Total)"),  
        tl_metrics.get("Training Time per Epoch"),  
        tl_metrics.get("Inference Speed"),  
        tl_metrics.get("Model Size (MB)"),  
        tl_metrics.get("Number of Parameters"),  
        tl_metrics.get("Trainable Parameters"),  
        tl_metrics.get("Non-trainable Parameters")
    ]
}

# Convert to DataFrame
comparison_df = pd.DataFrame(comparison_data)

comparison_df
# Out:
#                      Metric  Custom CNN  Transfer Learning (TL)
# 0       Validation Accuracy    0.943333            9.413334e-01
# 1         Training Accuracy    0.936667            9.756666e-01
# 2           Overfitting Gap   -0.006667            3.433329e-02
# 3     Training Time (Total)  568.345893            7.144994e+02
# 4   Training Time per Epoch   11.366918            2.381665e+01
# 5           Inference Speed    1.026129            3.122046e+00
# 6           Model Size (MB)    4.672599            9.807508e+00
# 7      Number of Parameters      393707            2.427459e+06
# 8      Trainable Parameters           -            2.341507e+06
# 9  Non-trainable Parameters           -            8.595200e+04

# %%
# Plot Accuracy Comparison
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['val_accuracy'], label="CNN Val Accuracy", linestyle="--")
plt.plot(full_tl_history["val_accuracy"], label="TL Val Accuracy", linestyle="-")
plt.ylim(0.75, 1)  # Keep scale fair
plt.title("Validation Accuracy: CNN vs. TL")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# Plot Loss Comparison
plt.subplot(1, 2, 2)
plt.plot(cnn_history.history['val_loss'], label="CNN Val Loss", linestyle="--")
plt.plot(full_tl_history["val_loss"], label="TL Val Loss", linestyle="-")
plt.ylim(0, max(max(cnn_history.history['val_loss']), max(full_tl_history["accuracy"])) * 1.1)
plt.title("Validation Loss: CNN vs. TL")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(8, 5))

cnn_train_val_diff = np.array(cnn_history.history['accuracy']) - np.array(cnn_history.history['val_accuracy'])
tl_train_val_diff = np.array(full_tl_history["accuracy"]) - np.array(full_tl_history["val_accuracy"])

plt.plot(cnn_train_val_diff, label="CNN Overfitting Gap", linestyle="--")
plt.plot(tl_train_val_diff, label="TL Overfitting Gap", linestyle="-")

plt.xlabel("Epochs")
plt.ylabel("Training - Validation Accuracy")
plt.title("Overfitting Analysis: CNN vs. TL")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.bar(["CNN", "Transfer Learning"], 
        [cnn_metrics["Training Time per Epoch"], tl_metrics["Training Time per Epoch"]], 
        color=["blue", "orange"])

plt.xlabel("Model")
plt.ylabel("Training Time per Epoch (sec)")
plt.title("Training Efficiency: CNN vs. TL")
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.bar(["CNN", "Transfer Learning"], 
        [cnn_metrics["Model Size (MB)"], tl_metrics["Model Size (MB)"]], 
        color=["blue", "orange"])

plt.xlabel("Model")
plt.ylabel("Model Size (MB)")
plt.title("Model Size Comparison: CNN vs. TL")
plt.show()

# %%
def plot_feature_maps_side_by_side(cnn_feature_maps, tl_feature_maps, scale_factor=10):
    # Determine number of rows (use the smaller list length to avoid mismatches)
    num_rows = min(len(cnn_feature_maps), len(tl_feature_maps))

    fig, axes = plt.subplots(num_rows, 2, figsize=(10, num_rows * 3))  # Adjust figure size dynamically
    fig.suptitle("Feature Map Comparison: CNN (Left) vs. Transfer Learning (Right)", fontsize=14)

    for i in range(num_rows):
        # Load CNN feature map
        cnn_img = Image.open(cnn_feature_maps[i])
        cnn_img = cnn_img.resize((cnn_img.width * scale_factor, cnn_img.height * scale_factor), Image.NEAREST)
        axes[i, 0].imshow(cnn_img)
        axes[i, 0].axis("off")
        axes[i, 0].set_title(f"CNN Layer {i+1}")

        # Load Transfer Learning feature map
        tl_img = Image.open(tl_feature_maps[i])
        tl_img = tl_img.resize((tl_img.width * scale_factor, tl_img.height * scale_factor), Image.NEAREST)
        axes[i, 1].imshow(tl_img)
        axes[i, 1].axis("off")
        axes[i, 1].set_title(f"TL Layer {i+1}")

    plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to fit title
    plt.show()

# Extract feature map file paths from metrics dictionaries
cnn_feature_maps = cnn_metrics["Feature Maps"]
tl_feature_maps = tl_metrics["Feature Maps"]

# Plot side-by-side feature maps
plot_feature_maps_side_by_side(cnn_feature_maps, tl_feature_maps)

# %%
comparison_df
# Out:
#                      Metric  Custom CNN  Transfer Learning (TL)
# 0       Validation Accuracy    0.943333            9.413334e-01
# 1         Training Accuracy    0.936667            9.756666e-01
# 2           Overfitting Gap   -0.006667            3.433329e-02
# 3     Training Time (Total)  568.345893            7.144994e+02
# 4   Training Time per Epoch   11.366918            2.381665e+01
# 5           Inference Speed    1.026129            3.122046e+00
# 6           Model Size (MB)    4.672599            9.807508e+00
# 7      Number of Parameters      393707            2.427459e+06
# 8      Trainable Parameters           -            2.341507e+06
# 9  Non-trainable Parameters           -            8.595200e+04

# %% [markdown]
# ## Comparison (183 words)
# The custom CNN model is clearly a winner in terms of metrics, efficiency and suitability.
# * CNN has 93.67% train_accuracy and 94.33% val_accuracy with tiny -0.67% underfitted while TL has 97.56% train_accuracy and only 94.13% val_accuracy, makeing the TL model slightly overfitted by 3.43%.
# * CNN model only has ~0.4M parameters (4.67MB) with 568s total training time, but the TL model has 2.4M parameters (9.81MB); some are trainable while some are not, which took 714s in total.
# * The CNN is also three-times faster than TL in predicting a new image input (1.02s vs. 3.12s inference time).
# * Since the given dataset is small, and there are only three classes, there is rarely a need for transfer learning; CNN performs good enough. Moreover, custom CNN doesn't have pre-defined input image size and can be modelled to work with current 32x32 images.
#
# **CNN**
# <br>+++ Fully customizable, lightweight
# <br>--- Requires programming expertise
# <br>--- While the training time may be fast, developing such an architecture from scratch takes up substantial resources.
#
# **TL**
# <br>+++ Easy to implement, high accuracy
# <br>--- Easy to be overfitted, computationally intensive
